# %% [markdown]
# # Clean and Combine Scraped Data
#
# A few steps:
#
# - Develop a formatter function (to be saved in the helpers.py file) to reformat raw csvs into a more manageable format.
# - Reformat raw csvs and save as one dataframe

# %%
import numpy as np
import pandas as pd
import os

from difflib import SequenceMatcher

# %%
loc = './Data/Raw Tables/'

fighter_urls = pd.read_csv('.\Data\FighterURLs.csv')
fighter_urls = fighter_urls.set_index('Name')

#We drop these fighters because their URLs were screwy
drop_bad_url = ['André Pederneiras',
                'Christian Morecraft',
                'Colin Fletcher',
                'David Baron',
                'Mark Schultz',
                'Jack Nilson']

# drop some people where we have difficulty with their URLs:
fighter_urls = fighter_urls.drop(drop_bad_url)
fighter_urls.loc['Daniel Kelly','URL'] = 'https://en.wikipedia.org/wiki/Dan_Kelly_(fighter)'
fighter_urls.loc['Maurice Smith','URL'] = 'https://en.wikipedia.org/wiki/Maurice_Smith_(kickboxer)'
fighter_urls.loc['Ryan Hall','URL'] = 'https://en.wikipedia.org/wiki/Ryan_Hall_(grappler)'
fighter_urls.sample(n=20)
# Out:
#                                                                    URL
# Name
# Rafael dos Anjos        https://en.wikipedia.org/wiki/Rafael_dos_Anjos
# Louis Smolka                https://en.wikipedia.org/wiki/Louis_Smolka
# Tedd Williams              https://en.wikipedia.org/wiki/Tedd_Williams
# Quinton Jackson          https://en.wikipedia.org/wiki/Quinton_Jackson
# Shane Carwin                https://en.wikipedia.org/wiki/Shane_Carwin
# Phil De Fries              https://en.wikipedia.org/wiki/Phil_De_Fries
# Bristol Marunde          https://en.wikipedia.org/wiki/Bristol_Marunde
# Joseph Benavidez        https://en.wikipedia.org/wiki/Joseph_Benavidez
# Mark Holst                    https://en.wikipedia.org/wiki/Mark_Holst
# Zach Light                    https://en.wikipedia.org/wiki/Zach_Light
# Charles McCarthy     https://en.wikipedia.org/wiki/Charles_McCarthy...
# Royce Gracie                https://en.wikipedia.org/wiki/Royce_Gracie
# Alexandre Ferreira   https://en.wikipedia.org/wiki/Alexandre_Ferrei...
# Mike Swick                    https://en.wikipedia.org/wiki/Mike_Swick
# Michael Chiesa            https://en.wikipedia.org/wiki/Michael_Chiesa
# Josh Grispi                  https://en.wikipedia.org/wiki/Josh_Grispi
# Mike Guymon                  https://en.wikipedia.org/wiki/Mike_Guymon
# Joe Doerksen         https://en.wikipedia.org/wiki/Joe_Doerksen_(fi...
# George Sotiropoulos  https://en.wikipedia.org/wiki/George_Sotiropoulos
# Fabiano Iha                  https://en.wikipedia.org/wiki/Fabiano_Iha

# %%
all_raw_csvs = []

for name in fighter_urls.index:
    filename = name.lower().replace(' ','_') +'.pkl'
    df = pd.read_pickle(loc + filename)
    df['Fighter'] = name
    all_raw_csvs.append(df)

raw_data = pd.concat(all_raw_csvs)
raw_data.head()
# Out:
#      Res.   Record       Opponent                 Method  \
# 0    Loss  30–14–1   Justin Salas       Decision (split)
# 1    Loss  30–13–1  Tony Ferguson  TKO (corner stoppage)
# 2     Win  30–12–1    Joe Brammer   Decision (unanimous)
# 3    Loss  29–12–1   Ross Pearson  TKO (doctor stoppage)
# 4     Win  29–11–1   Shane Nelson   Decision (unanimous)
#
#                             Event                                       Date  \
# 0  UFC on Fox: Johnson vs. Moraga       000000002013-07-27-0000July 27, 2013
# 1                         UFC 135  000000002011-09-24-0000September 24, 2011
# 2                         UFC 114        000000002010-05-29-0000May 29, 2010
# 3                         UFC 105   000000002009-11-14-0000November 14, 2009
# 4                         UFC 101      000000002009-08-08-0000August 8, 2009
#
#   Round  Time                                   Location Notes      birthday  \
# 0     3  5:00         Seattle, Washington, United States          1980-12-09
# 1     1  5:00            Denver, Colorado, United States          1980-12-09
# 2     3  5:00           Las Vegas, Nevada, United States          1980-12-09
# 3     2  4:34                        Manchester, England          1980-12-09
# 4     3  5:00  Philadelphia, Pennsylvania, United States          1980-12-09
#
#        Fighter
# 0  Aaron Riley
# 1  Aaron Riley
# 2  Aaron Riley
# 3  Aaron Riley
# 4  Aaron Riley

# %%
raw_data.shape
# Out:
# (26681, 14)

# %% [markdown]
# ### Format Date Column

# %%
def format_date(date):
    if len(date) > 23:
        return pd.to_datetime(date[8:18],format='%Y-%m-%d')
    else:
        return pd.to_datetime(date)

raw_data['Date_new'] = raw_data['Date'].apply(format_date)

raw_data[['Date','Date_new']].sample(n=5)
# Out:
#                                         Date   Date_new
# 15  000000002007-12-29-0000December 29, 2007 2007-12-29
# 10     000000002013-03-16-0000March 16, 2013 2013-03-16
# 10       000000002007-07-07-0000July 7, 2007 2007-07-07
# 2   000000002011-02-20-0000February 20, 2011 2011-02-20
# 1      000000001998-03-13-0000March 13, 1998 1998-03-13

# %%
assert np.sum(raw_data.Date_new.isnull()) == 0

# %% [markdown]
# ### Re-write 'opponent' column
#
# We need to make sure that our list of names matches the opponent names. To check this, we will do a few thing:
#
#     1. Make sure our 'Fighter' column is a subset of our 'Opponent' Column.
#     2. For all unmatched opponents, we need to find the most similar fighter name. If we think we have a match, we'll add it to a dictionary that will be responsible for transforming opponent names.
#     3. For the 'other' fights, we have to make sure they are actually 'others' and not mispellings..

# %%
fighters = raw_data.Fighter.unique()
opponents = raw_data.Opponent.unique()
subset_boolean = np.array([nm in opponents for nm in fighters])

def fighter_subset_perc():
    perc = len(set(raw_data.Opponent).intersection(set(raw_data.Fighter)))/len(set(raw_data.Fighter))
    print('Subset percentage: {}%'.format(str(perc*100)[:5]))
    
fighter_subset_perc()
# Out:
# Subset percentage: 96.99%

# %%
unmatched_fighters = fighters[~subset_boolean]
unmatched_fighters
# Out:
# array(['Alexey Oleinik', 'Alptekin Özkiliç', 'Antonio Braga Neto',
#        'Damir Hadzovic', 'Dan Spohn', 'Edgar Garcia', 'James Moontasri',
#        'Jan Blachowicz', 'Jarred Brooks', 'Jon Olav Einemo', 'João Roque',
#        'Jussier da Silva', 'Jörgen Kruth', 'Kevin Ferguson',
#        'Lipeng Zhang', 'Marco Polo Reyes', 'Mauricio Rua',
#        'Mirko Filipović', 'Mostapha Al-Turk', 'Nathan Quarry',
#        'Renee Forte', 'Robert Drysdale', 'Rolles Gracie',
#        'Rony Mariano Bezerra', 'Royston Wee', 'Sako Chivitchian',
#        "Sean O'Malley", 'Sergio Moraes', 'Teemu Packalen', 'Tiequan Zhang',
#        'Yuta Sasaki'], dtype=object)

# %%
def common_substring_length(name1, name2):
    return SequenceMatcher(None, name1, name2).find_longest_match(0,len(name1),0,len(name2)).size

unmatched_similarities = {}

for uf in unmatched_fighters:
    print('Working on: {}'.format(uf))
    similiary = pd.Series(np.nan,index=opponents)
    
    for op in similiary.index:
        similiary.loc[op] = common_substring_length(uf, op)
        
    unmatched_similarities[uf] = similiary.sort_values(ascending=False).head(10)
# Out:
# Working on: Alexey Oleinik
# Working on: Alptekin Özkiliç
# Working on: Antonio Braga Neto
# Working on: Damir Hadzovic
# Working on: Dan Spohn
# Working on: Edgar Garcia
# Working on: James Moontasri
# Working on: Jan Blachowicz
# Working on: Jarred Brooks
# Working on: Jon Olav Einemo
# Working on: João Roque
# Working on: Jussier da Silva
# Working on: Jörgen Kruth
# Working on: Kevin Ferguson
# Working on: Lipeng Zhang
# Working on: Marco Polo Reyes
# Working on: Mauricio Rua
# Working on: Mirko Filipović
# Working on: Mostapha Al-Turk
# Working on: Nathan Quarry
# Working on: Renee Forte
# Working on: Robert Drysdale
# Working on: Rolles Gracie
# Working on: Rony Mariano Bezerra
# Working on: Royston Wee
# Working on: Sako Chivitchian
# Working on: Sean O'Malley
# Working on: Sergio Moraes
# Working on: Teemu Packalen
# Working on: Tiequan Zhang
# Working on: Yuta Sasaki

# %%
for uf in unmatched_similarities:
    print()
    print(uf)
    print(fighter_urls.loc[uf])
    print('-------------')
    print(unmatched_similarities[uf])
# Out:
# Sergio Moraes
# URL    https://en.wikipedia.org/wiki/Sergio_Moraes
# Name: Sergio Moraes, dtype: object
# -------------
# Sérgio Moraes           11.0
# Sergio Melo              8.0
# Sergio Matias            8.0
# Luis Sergio Melo Jr.     8.0
# Adriano Moraes           8.0
# Sergio Leal              7.0
# Sergio Soares            7.0
# Daniel Moraes            7.0
# Sergio da Silva          7.0
# Sergio Gomez             7.0
# dtype: float64
#
# Robert Drysdale
# URL    https://en.wikipedia.org/wiki/Robert_Drysdale
# Name: Robert Drysdale, dtype: object
# -------------
# Robert Lalonde      7.0
# Robert Wynne        7.0
# Robert Whittaker    7.0
# Robert Hogan        7.0
# Robert Neal         7.0
# Robert Thompson     7.0
# Robert Irizarry     7.0
# Robert Fabrizi      7.0
# Robert Lieske       7.0
# Robert Balicki      7.0
# dtype: float64
#
# João Roque
# URL    https://en.wikipedia.org/wiki/João_Roque
# Name: João Roque, dtype: object
# -------------
# RoqueJoão Roque         10.0
# Roque Oliver             5.0
# João Paulo Rodrigues     5.0
# João Paulo Almeida       5.0
# João Antonio Gois        5.0
# João Herdy               5.0
# João Zeferino            5.0
# João Paulo Melo          5.0
# João João                5.0
# João Paulo Pereira       5.0
# dtype: float64
#
# Yuta Sasaki
# URL    https://en.wikipedia.org/wiki/Yuta_Sasaki
# Name: Yuta Sasaki, dtype: object
# -------------
# Ulka Sasaki          8.0
# Yuki Sasaki          7.0
# Shinji Sasaki        7.0
# Kyosuke Sasaki       7.0
# Kensuke Sasaki       7.0
# Ryuta Sakurai        6.0
# Yuta Nezu            5.0
# Katsuhisa Akasaki    5.0
# Yuta Nakamura        5.0
# Johnny Iwasaki       5.0
# dtype: float64
#
# Renee Forte
# URL    https://en.wikipedia.org/wiki/Renee_Forte
# Name: Renee Forte, dtype: object
# -------------
# Charlie Fortec     7.0
# Renée Forte        7.0
# Jesse Forbes       5.0
# Ryan Fortin        5.0
# Diego Fortunato    5.0
# Marcel Fortuna     5.0
# Nate Ford          5.0
# Rene Tremblay      4.0
# Cortez Coleman     4.0
# Jorge Cortez       4.0
# dtype: float64
#
# Sean O'Malley
# URL    https://en.wikipedia.org/wiki/Sean_O'Malley_(f...
# Name: Sean O'Malley, dtype: object
# -------------
# Dorlan O'Malley     11.0
# Mike O'Malley        9.0
# Pat O'Malley         9.0
# Sean O'Connell       7.0
# Brendan O'Reilly     5.0
# Sean Brockmole       5.0
# Sean Spencer         5.0
# Sean Sherk           5.0
# Sean Salmon          5.0
# Sean Bormet          5.0
# dtype: float64
#
# Antonio Braga Neto
# URL    https://en.wikipedia.org/wiki/Antonio_Braga_Neto
# Name: Antonio Braga Neto, dtype: object
# -------------
# Antônio Braga Neto    14.0
# Antonio Banuelos       9.0
# Antonio Duarte         8.0
# Antonio Lepe           8.0
# Antonio Mendes         8.0
# João Antonio Gois      8.0
# Antonio Carvalho       8.0
# Antonio Marcos         8.0
# Antonio McKee          8.0
# Diego Braga Alves      8.0
# dtype: float64
#
# Royston Wee
# URL    https://en.wikipedia.org/wiki/Royston_Wee
# Name: Royston Wee, dtype: object
# -------------
# Houston Dorr            5.0
# Jason Webb              5.0
# Cameron Wells           5.0
# Brad Royster            5.0
# Preston Scharf          5.0
# Denniston Sutherland    5.0
# Sheldon Westcott        5.0
# Johnathon Wesson        5.0
# Crafton Wallace         5.0
# Treston Thomison        5.0
# dtype: float64
#
# Lipeng Zhang
# URL    https://en.wikipedia.org/wiki/Zhang_Lipeng
# Name: Lipeng Zhang, dtype: object
# -------------
# Yongqiang Zhang       8.0
# Zhang Lipeng          6.0
# Yonglong Zhu          5.0
# Zhang Tiequan         5.0
# Chang Hyun Kim        4.0
# Bernueng Sakhomsin    4.0
# Yanfei Zhao           4.0
# Chang Seob Lee        4.0
# Haeng Ki Kim          4.0
# Jonathan Bilton       3.0
# dtype: float64
#
# Mauricio Rua
# URL    https://en.wikipedia.org/wiki/Mauricio_Rua
# Name: Mauricio Rua, dtype: object
# -------------
# Mauricio Reis              10.0
# Mauricio dos Santos Jr.     9.0
# Mauricio Santos             9.0
# Mauricio Menegueti          9.0
# Mauricio Chueke             9.0
# Mauricio Alves              9.0
# Mauricio Castillo           9.0
# Mauricio Machado            9.0
# Mauricio Alonso             9.0
# Maurício Rua                7.0
# dtype: float64
#
# Mostapha Al-Turk
# URL    https://en.wikipedia.org/wiki/Mostapha_al-Turk
# Name: Mostapha Al-Turk, dtype: object
# -------------
# Mostapha al-Turk         9.0
# Luiz Henrique Tosta      4.0
# Ralph Costa              4.0
# Ernest Kostanyan         4.0
# Marcelo Costa            4.0
# Gokhan Turkyilmaz        4.0
# Paulo Costa              4.0
# Raphael Assunção         4.0
# Rafael da Silva Alves    4.0
# Laerte Costa e Silva     4.0
# dtype: float64
#
# Edgar Garcia
# URL    https://en.wikipedia.org/wiki/Edgar_Garcia
# Name: Edgar Garcia, dtype: object
# -------------
# Edgar García                        10.0
# Jessie Garcia                        7.0
# Aaron Garcia                         7.0
# Wesley Martins Garcia de Almeida     7.0
# Marvin Garcia                        7.0
# Dave Garcia                          7.0
# Alex Garcia                          7.0
# Eric Garcia                          7.0
# Vanderci Garcia                      7.0
# Chris Garcia                         7.0
# dtype: float64
#
# Rolles Gracie
# URL    https://en.wikipedia.org/wiki/Rolles_Gracie
# Name: Rolles Gracie, dtype: object
# -------------
# Rolles Gracie Jr.    13.0
# Charles Gracie       10.0
# Roger Gracie          7.0
# Royler Gracie         7.0
# Igor Gracie           7.0
# Ralph Gracie          7.0
# Renzo Gracie          7.0
# Rodrigo Gracie        7.0
# Kron Gracie           7.0
# Ralek Gracie          7.0
# dtype: float64
#
# James Moontasri
# URL    https://en.wikipedia.org/wiki/James_Moontasri
# Name: James Moontasri, dtype: object
# -------------
# James MacCallister    7.0
# James Meal            7.0
# James Mathews         7.0
# James McSweeney       7.0
# James Minson          7.0
# James Meals           7.0
# James Mulheron        7.0
# James Martinez        7.0
# James Warfield        6.0
# James Vick            6.0
# dtype: float64
#
# Jörgen Kruth
# URL    https://en.wikipedia.org/wiki/Jörgen_Kruth
# Name: Jörgen Kruth, dtype: object
# -------------
# Ken Kronenberg      5.0
# Eben Kaneshiro      4.0
# Štefan Krajči       4.0
# Scott Jorgensen     4.0
# Ben Konecnec        4.0
# Warren Kee          4.0
# Steven Kennedy      4.0
# Aaron Kreke         4.0
# Ed de Kruijf        4.0
# Danny van Bergen    4.0
# dtype: float64
#
# Nathan Quarry
# URL    https://en.wikipedia.org/wiki/Nathan_Quarry
# Name: Nathan Quarry, dtype: object
# -------------
# Nathan McCabe    7.0
# Nathan Oliver    7.0
# Nathan Fussel    7.0
# Nathan Jones     7.0
# Nathan Howe      7.0
# Nathan Gunn      7.0
# Nathan Coy       7.0
# Nathan Brown     7.0
# Nathan Schut     7.0
# Nathan Aber      7.0
# dtype: float64
#
# Kevin Ferguson
# URL    https://en.wikipedia.org/wiki/Kevin_Ferguson
# Name: Kevin Ferguson, dtype: object
# -------------
# Jeremy Ferguson     9.0
# Tony Ferguson       9.0
# Robert Ferguson     9.0
# James Ferguson      9.0
# Josh Ferguson       9.0
# David Ferguson      9.0
# Bruce Ferguson      9.0
# Anthony Ferguson    9.0
# Kevin Filal         7.0
# Kevin Oliver        6.0
# dtype: float64
#
# Rony Mariano Bezerra
# URL    https://en.wikipedia.org/wiki/Rony_Mariano_Bez...
# Name: Rony Mariano Bezerra, dtype: object
# -------------
# Alexandre Bezerra     8.0
# Artur Mariano         8.0
# Adriano Bernardo      8.0
# Marcone Bezerra       8.0
# Jorge Luis Bezerra    8.0
# Tony Martin           7.0
# Anthony Marti         7.0
# Tony Marcos           7.0
# Adriano Balby         7.0
# Cristiano Bob         6.0
# dtype: float64
#
# Alptekin Özkiliç
# URL    https://en.wikipedia.org/wiki/Alptekin_Özkiliç
# Name: Alptekin Özkiliç, dtype: object
# -------------
# Alp Ozkilic        5.0
# Hideki Sekine      4.0
# Tateki Matsuda     4.0
# Akin Duran         4.0
# Philip Perez       3.0
# Aaron Wilkinson    3.0
# Gavin Tucker       3.0
# Justin Jones       3.0
# Iouri Bekichev     3.0
# Justin Lemke       3.0
# dtype: float64
#
# Mirko Filipović
# URL    https://en.wikipedia.org/wiki/Mirko_Filipović
# Name: Mirko Filipović, dtype: object
# -------------
# Mirko Cro Cop              6.0
# Andre Fili                 5.0
# Paulo Filho                5.0
# Sergey Filimonov           5.0
# Edgar Castaldelli Filho    4.0
# Perry Filkins              4.0
# Ivan Shtirkov              4.0
# Darko Krbanjevic           4.0
# Dilson Filho               4.0
# Philip Preece              4.0
# dtype: float64
#
# Jon Olav Einemo
# URL    https://en.wikipedia.org/wiki/Jon_Olav_Einemo
# Name: Jon Olav Einemo, dtype: object
# -------------
# John-Olav Einemo       11.0
# Jon Owens               5.0
# Wellington Oliveira     5.0
# Brandon Olsen           5.0
# Jaroslav Poborský       4.0
# Jon Tuck                4.0
# Jon Fitch               4.0
# Jon Weidler             4.0
# Miroslav Strbak         4.0
# Vyacheslav Kiselyov     4.0
# dtype: float64
#
# Jussier da Silva
# URL    https://en.wikipedia.org/wiki/Jussier_da_Silva
# Name: Jussier da Silva, dtype: object
# -------------
# Peter da Silva                 11.0
# Eder da Silva                  11.0
# Genair da Silva                10.0
# Gilmar da Silva                10.0
# Henrique da Silva               9.0
# Diego Henrique da Silva         9.0
# Celivaldo da Silva              9.0
# Claudionor Cardoso da Silva     9.0
# Rafael da Silva Alves           9.0
# Marcos da Silva                 9.0
# dtype: float64
#
# Tiequan Zhang
# URL    https://en.wikipedia.org/wiki/Tiequan_Zhang
# Name: Tiequan Zhang, dtype: object
# -------------
# Zhang Tiequan            7.0
# Yongqiang Zhang          6.0
# Zhang Lipeng             5.0
# Juan Barrantes           4.0
# Adrian Zielinski         4.0
# Roman Zentsov            4.0
# Juan Francisco Espino    4.0
# Chang Hyun Kim           4.0
# Juan Manuel Suárez       4.0
# Juan Manuel Torres       4.0
# dtype: float64
#
# Sako Chivitchian
# URL    https://en.wikipedia.org/wiki/Sako_Chivitchian
# Name: Sako Chivitchian, dtype: object
# -------------
# Ritchie Ivory         5.0
# Mauro Chimento Jr.    5.0
# Lindon Mitchell       4.0
# Junpei Chikano        4.0
# Alessio Di Chirico    4.0
# David Mitchell        4.0
# Mitch Clarke          4.0
# Chris Chiasson        4.0
# Michael Chiesa        4.0
# Mitch Coats           4.0
# dtype: float64
#
# Jarred Brooks
# URL    https://en.wikipedia.org/wiki/Jarred_Brooks
# Name: Jarred Brooks, dtype: object
# -------------
# Kevin Brooks         7.0
# E.J. Brooks          7.0
# Will Brooks          7.0
# Carlos Brooks        7.0
# Donald Brook         7.0
# Theo Brooks          7.0
# Taylor Brooks        7.0
# Tyler Brooks         7.0
# Jonathan Brookins    6.0
# David Brown          5.0
# dtype: float64
#
# Marco Polo Reyes
# URL    https://en.wikipedia.org/wiki/Marco_Polo_Reyes
# Name: Marco Polo Reyes, dtype: object
# -------------
# Polo Reyes         10.0
# Marco Vinicios      6.0
# Marco Daniels       6.0
# Yahir Reyes         6.0
# Richie Reyes        6.0
# Marco Beltrán       6.0
# Manny Reyes Jr.     6.0
# Josh Reyes          6.0
# Jon Delos Reyes     6.0
# Jon delos Reyes     6.0
# dtype: float64
#
# Teemu Packalen
# URL    https://en.wikipedia.org/wiki/Teemu_Packalen
# Name: Teemu Packalen, dtype: object
# -------------
# Teemu Nurkkala          6.0
# Camrann Pacheco         4.0
# Valentino Petrescu      4.0
# Tony Valente            4.0
# Valentin Siouljine      4.0
# Chance Whalen           4.0
# Valentijn Overeem       4.0
# Michael Pacholik        4.0
# Brylan Van Artsdalen    4.0
# Steve Magdaleno         4.0
# dtype: float64
#
# Jan Blachowicz
# URL    https://en.wikipedia.org/wiki/Jan_Blachowicz
# Name: Jan Blachowicz, dtype: object
# -------------
# Jan Błachowicz     8.0
# Jason Black        6.0
# Aaron Blackwell    6.0
# Tom Blackledge     5.0
# Danny Black        5.0
# Mark Blackburn     5.0
# Raymond Black      5.0
# Fausto Black       5.0
# Zack Blackwood     5.0
# Justin Blasich     5.0
# dtype: float64
#
# Dan Spohn
# URL    https://en.wikipedia.org/wiki/Dan_Spohn
# Name: Dan Spohn, dtype: object
# -------------
# Daniel Spohn       6.0
# Ryan Spann         5.0
# Bojan Spalevic     5.0
# Jonathan Spears    5.0
# Bojan Spalević     5.0
# Dan Swift          5.0
# Dan Shenk          5.0
# Dylan Sprawl       5.0
# Sean Spencer       5.0
# Dan Severn         5.0
# dtype: float64
#
# Damir Hadzovic
# URL    https://en.wikipedia.org/wiki/Damir_Hadzovic
# Name: Damir Hadzovic, dtype: object
# -------------
# Damir Hadžović        9.0
# Damir Mirenic         6.0
# Damir Mihajlovic      6.0
# Urajimir Hoodenkin    5.0
# Bobir Hasanov         5.0
# Shamir Maromegob      5.0
# Samir Seif            5.0
# David Ramirez         4.0
# Thomas Ramirez        4.0
# Daniel Stenovich      4.0
# dtype: float64
#
# Alexey Oleinik
# URL    https://en.wikipedia.org/wiki/Alexey_Oleinik
# Name: Alexey Oleinik, dtype: object
# -------------
# Andrey Oleinik        10.0
# Alexey Stepanov        7.0
# Alexey Artemenko       7.0
# Alexey Kudin           7.0
# Alexey Efremov         7.0
# Alexey Prokofiev       7.0
# Casey Olson            5.0
# Alexei Belyaev         5.0
# Alexei Nazarov         5.0
# Alexei Vezelozorov     5.0
# dtype: float64

# %%
# We drop these fighters because they are never opponents in the mma fight record tables. This means
# they almost wholely fight fighters outside our dataset.

drop_outsider =['Alexey Oleinik',
                'Sako Chivitchian',
                'Royston Wee',
                'Jörgen Kruth',
                'James Moontasri',
                'Teemu Nurkkala',
                'Robert Drysdale',
                'Jarred Brooks',
                "Sean O'Malley",
                'Teemu Packalen']

raw_data = raw_data.loc[~raw_data['Fighter'].isin(drop_outsider),:]

# %%
opponent_name_mapper = {}
opponent_name_mapper['Zhang Lipeng'] = 'Lipeng Zhang'
opponent_name_mapper['Jussier Formiga'] = 'Jussier da Silva'
opponent_name_mapper['Ulka Sasaki'] = 'Yuta Sasaki'
opponent_name_mapper['Mirko Cro Cop'] = 'Mirko Filipović'
opponent_name_mapper['Antônio Braga Neto'] = 'Antonio Braga Neto'
opponent_name_mapper['Polo Reyes'] = 'Marco Polo Reyes'
opponent_name_mapper['Alp Ozkilic'] = 'Alptekin Özkiliç'
opponent_name_mapper['Nate Quarry'] = 'Nathan Quarry'
opponent_name_mapper['Rolles Gracie Jr.'] = 'Rolles Gracie'
opponent_name_mapper['Damir Hadžović'] = 'Damir Hadzovic'
opponent_name_mapper['Jan Błachowicz'] = 'Jan Blachowicz'
opponent_name_mapper['Daniel Spohn'] = 'Dan Spohn'
opponent_name_mapper['Sérgio Moraes'] = 'Sergio Moraes'
opponent_name_mapper['Renée Forte'] = 'Renee Forte'
opponent_name_mapper['Edgar García'] = 'Edgar Garcia'
opponent_name_mapper['Mostapha al-Turk'] = 'Mostapha Al-Turk'
opponent_name_mapper['RoqueJoão Roque'] = 'João Roque'
opponent_name_mapper['John-Olav Einemo'] = 'Jon Olav Einemo'
opponent_name_mapper['Zhang Tiequan'] = 'Tiequan Zhang'
opponent_name_mapper['Rony Jason'] = 'Rony Mariano Bezerra'
opponent_name_mapper['Maurício Rua'] = 'Mauricio Rua'
opponent_name_mapper['Maurício Rua'] = 'Mauricio Rua'
opponent_name_mapper['Kimbo Slice'] = 'Kevin Ferguson'

raw_data['Opponent'] = raw_data['Opponent'].apply(lambda x: opponent_name_mapper[x] if x in opponent_name_mapper else x)

# %%
fighter_subset_perc()
# Out:
# Subset percentage: 100.0%

# %% [markdown]
# ### Now we need to figure out which opponents that aren't on our list are actually just misspellings..

# %%
def perc_opponent_recognized():
    perc = np.mean([nm in fighters for nm in raw_data.Opponent])
    print('Percent opponents are familiar fighters: {}%'.format(str(perc*100)[:5]))
    
perc_opponent_recognized()
# Out:
# Percent opponents are familiar fighters: 38.36%

# %% [markdown]
# Hm, OK, let's go by the most frequent opponents seen.

# %%
unrecognized = set(opponents) - set(fighters)
unrecognized_counts = raw_data.loc[raw_data.Opponent.isin(unrecognized),'Opponent'].value_counts()
unrecognized_counts.head(15)
# Out:
# Osami Shibuya        33
# Ikuhisa Minowa       31
# Kiuma Kunioku        30
# Shannon Ritch        30
# Fedor Emelianenko    27
# Ryushi Yanagisawa    27
# Masakatsu Funaki     25
# Minoru Suzuki        24
# Dennis Reed          23
# Igor Vovchanchyn     20
# Kazuo Misaki         20
# Takafumi Ito         19
# Shinya Aoki          18
# Victor Moreno        18
# Derrick Noble        17
# Name: Opponent, dtype: int64

# %% [markdown]
# OK, let's consider anyone with more than 10 fights. We'll look at their similarities with fighters we have and see if we find anything.

# %%
opponents_over10 = unrecognized_counts.index[unrecognized_counts>15]
unmatched_similarities_opp = {}

for op in opponents_over10:
    print('Working on: {}'.format(op))
    similiary = pd.Series(np.nan,index=fighters)
    
    for fg in similiary.index:
        similiary.loc[fg] = common_substring_length(fg, op)
        
    unmatched_similarities_opp[op] = similiary.sort_values(ascending=False).head(10)
# Out:
# Working on: Osami Shibuya
# Working on: Ikuhisa Minowa
# Working on: Kiuma Kunioku
# Working on: Shannon Ritch
# Working on: Fedor Emelianenko
# Working on: Ryushi Yanagisawa
# Working on: Masakatsu Funaki
# Working on: Minoru Suzuki
# Working on: Dennis Reed
# Working on: Igor Vovchanchyn
# Working on: Kazuo Misaki
# Working on: Takafumi Ito
# Working on: Shinya Aoki
# Working on: Victor Moreno
# Working on: Derrick Noble
# Working on: Ruben Villareal
# Working on: Kiyoshi Tamura
# Working on: Satoru Kitaoka
# Working on: Manabu Yamada
# Working on: William Hill
# Working on: Hiromitsu Kanehara
# Working on: Thomas Denny
# Working on: Tony Lopez
# Working on: Paul Jenkins

# %%
for op in unmatched_similarities_opp:
    print()
    print(op)
    print('-------------')
    print(unmatched_similarities_opp[op])
# Out:
# Kiyoshi Tamura
# -------------
# Issei Tamura             8.0
# Kuniyoshi Hironaka       7.0
# Tsuyoshi Kohsaka         6.0
# Kazuhiro Nakamura        5.0
# Satoshi Honma            5.0
# Keita Nakamura           5.0
# Michinori Tanaka         4.0
# Yoshiyuki Yoshida        4.0
# Dustin Kimura            4.0
# Gadzhimurad Antigulov    4.0
# dtype: float64
#
# Osami Shibuya
# -------------
# Jake Shields          4.0
# Kamal Shalorus        3.0
# Wanderlei Silva       3.0
# Jimi Manuwa           3.0
# Ken Shamrock          3.0
# Genki Sudo            3.0
# Keiichiro Yamamiya    3.0
# Kazushi Sakuraba      3.0
# Andrei Semenov        3.0
# Anthony Hamilton      3.0
# dtype: float64
#
# Dennis Reed
# -------------
# Dennis Siver        7.0
# Dennis Hallman      7.0
# Dennis Bermudez     7.0
# Luis Ramos          4.0
# Yosdenis Cedeno     4.0
# Denis Kang          4.0
# Chris Kelades       3.0
# Chris Leben         3.0
# Chris Holdsworth    3.0
# Chris Haseman       3.0
# dtype: float64
#
# Hiromitsu Kanehara
# -------------
# Masanori Kanehara     9.0
# Kuniyoshi Hironaka    4.0
# Kyung Ho Kang         4.0
# Hatsu Hioki           4.0
# Denis Kang            4.0
# Eiji Mitsuoka         4.0
# Mizuto Hirota         4.0
# Katsuhisa Fujii       3.0
# Katsunori Kikuno      3.0
# Scott Smith           3.0
# dtype: float64
#
# Ruben Villareal
# -------------
# Gian Villante        7.0
# Yuri Villefort       5.0
# Danillo Villefort    5.0
# Melvin Guillard      5.0
# Reuben Duran         5.0
# T.J. Dillashaw       4.0
# Ryan LaFlare         4.0
# Milton Vieira        4.0
# Willamy Freire       4.0
# Tarec Saffiedine     3.0
# dtype: float64
#
# Tony Lopez
# -------------
# Matthew Lopez           6.0
# Anthony Lapsley         5.0
# Tony DeSouza            5.0
# Tony Ferguson           5.0
# Tony Fryklund           5.0
# Tony Halme              5.0
# Tony Martin             5.0
# Anthony Pettis          4.0
# Rony Mariano Bezerra    4.0
# Anthony Smith           4.0
# dtype: float64
#
# Manabu Yamada
# -------------
# Kenichi Yamamoto       5.0
# Keiichiro Yamamiya     5.0
# Norifumi Yamamoto      5.0
# Damacio Page           3.0
# Emmanuel Yarborough    3.0
# Reza Madadi            3.0
# Ricardo Lamas          3.0
# Alexander Yakovlev     3.0
# Jimi Manuwa            3.0
# Aljamain Sterling      3.0
# dtype: float64
#
# Igor Vovchanchyn
# -------------
# Igor Pokrajac            5.0
# Alexander Volkanovski    4.0
# Diego Sanchez            4.0
# David Branch             4.0
# Eddie Sanchez            4.0
# Michael Kuiper           3.0
# Maximo Blanco            3.0
# Francis Carmont          3.0
# Francisco Rivera         3.0
# Francisco Trinaldo       3.0
# dtype: float64
#
# Derrick Noble
# -------------
# Derrick Lewis       8.0
# Patrick Cummins     5.0
# Erick Silva         5.0
# Patrick Côté        5.0
# Patrick Holohan     5.0
# Patrick Smith       5.0
# Patrick Williams    5.0
# Nick Ring           4.0
# Dominick Cruz       4.0
# Nick Denis          4.0
# dtype: float64
#
# William Hill
# -------------
# William Macário     8.0
# Tedd Williams       7.0
# Patrick Williams    7.0
# Pete Williams       7.0
# Corey Hill          5.0
# Willamy Freire      4.0
# Will Campuzano      4.0
# Will Brooks         4.0
# Sam Hoger           4.0
# Phillipe Nover      4.0
# dtype: float64
#
# Shinya Aoki
# -------------
# Takeya Mizugaki             3.0
# War Machine                 3.0
# Jake Shields                3.0
# Mostapha Al-Turk            3.0
# Hatsu Hioki                 3.0
# Michinori Tanaka            3.0
# Tatsuya Kawajiri            3.0
# Yushin Okami                3.0
# Jonathan Brookins           3.0
# Rameau Thierry Sokoudjou    2.0
# dtype: float64
#
# Minoru Suzuki
# -------------
# Michinori Tanaka    4.0
# Kazuki Tokudome     4.0
# Takanori Gomi       3.0
# João Zeferino       3.0
# Jorge Patino        3.0
# Amar Suloev         3.0
# Ali Bagautinov      3.0
# Kamal Shalorus      3.0
# Katsunori Kikuno    3.0
# Chan Sung Jung      3.0
# dtype: float64
#
# Ryushi Yanagisawa
# -------------
# Kazushi Sakuraba        5.0
# Kenichi Yamamoto        5.0
# Dongi Yang              5.0
# Kuniyoshi Hironaka      4.0
# Satoshi Honma           4.0
# Tsuyoshi Kohsaka        4.0
# Brian Gassaway          4.0
# Vladimir Matyushenko    4.0
# Yasuhiro Urushitani     4.0
# Norifumi Yamamoto       4.0
# dtype: float64
#
# Fedor Emelianenko
# -------------
# Rob Emerson             4.0
# Li Jingliang            4.0
# Anton Kuivanen          4.0
# Vladimir Matyushenko    4.0
# Hector Lombard          3.0
# Cristiano Marcello      3.0
# Iliarde Santos          3.0
# Sean Soriano            3.0
# Igor Pokrajac           3.0
# Hugo Viana              3.0
# dtype: float64
#
# Kazuo Misaki
# -------------
# Kazuo Takahashi          6.0
# Kazuhiro Nakamura        4.0
# Kazushi Sakuraba         4.0
# Mario Miranda            4.0
# Yuki Sasaki              4.0
# Yuta Sasaki              4.0
# Dokonjonosuke Mishima    4.0
# Kazuki Tokudome          4.0
# Carmelo Marrero          3.0
# Matt Mitrione            3.0
# dtype: float64
#
# Paul Jenkins
# -------------
# Trent Jenkins     8.0
# Paul Jones        6.0
# Paul Creighton    5.0
# Paul Sass         5.0
# Paul Felder       5.0
# Paul Taylor       5.0
# Paul Varelans     5.0
# Paul Daley        5.0
# Paul Kelly        5.0
# Paul Buentello    5.0
# dtype: float64
#
# Takafumi Ito
# -------------
# Norifumi Yamamoto     5.0
# Takanori Gomi         4.0
# Daiju Takase          4.0
# Kazuo Takahashi       4.0
# Jimi Manuwa           3.0
# Kazuhiro Nakamura     3.0
# Michinori Tanaka      3.0
# Tsuyoshi Kohsaka      3.0
# Kuniyoshi Hironaka    3.0
# Takeya Mizugaki       3.0
# dtype: float64
#
# Masakatsu Funaki
# -------------
# Hatsu Hioki          5.0
# Tatsuya Kawajiri     4.0
# Katsuhisa Fujii      4.0
# Katsunori Kikuno     4.0
# Masanori Kanehara    4.0
# Yuta Sasaki          4.0
# Tsuyoshi Kohsaka     4.0
# Ricardo Funch        4.0
# Yuki Sasaki          4.0
# Jutaro Nakao         3.0
# dtype: float64
#
# Ikuhisa Minowa
# -------------
# Katsuhisa Fujii          6.0
# Takeya Mizugaki          4.0
# Elvis Sinosic            3.0
# David Michaud            3.0
# Vitor Miranda            3.0
# Jorge Patino             3.0
# Eiji Mitsuoka            3.0
# Dokonjonosuke Mishima    3.0
# John Howard              3.0
# Cole Miller              3.0
# dtype: float64
#
# Shannon Ritch
# -------------
# Shannon Gugerty    8.0
# Aaron Riley        5.0
# Shane Roller       4.0
# Jason Reinhardt    4.0
# Vernon White       4.0
# Jon Fitch          4.0
# Mitch Clarke       4.0
# Mitch Gagnon       4.0
# David Mitchell     4.0
# Wilson Reis        4.0
# dtype: float64
#
# Thomas Denny
# -------------
# Thomas Almeida      7.0
# Ryan Thomas         6.0
# Din Thomas          6.0
# Nick Thompson       4.0
# Kenny Robertson     4.0
# Dennis Hallman      4.0
# Dennis Bermudez     4.0
# Stephen Thompson    4.0
# Nick Denis          4.0
# Oli Thompson        4.0
# dtype: float64
#
# Satoru Kitaoka
# -------------
# Koji Kitao        6.0
# Satoshi Honma     4.0
# Takenori Sato     4.0
# Viktor Pešta      3.0
# Hayato Sakurai    3.0
# Eiji Mitsuoka     3.0
# Kyle Kingsbury    3.0
# Vitor Miranda     3.0
# Vitor Belfort     3.0
# Kit Cope          3.0
# dtype: float64
#
# Victor Moreno
# -------------
# Hector Ramirez    5.0
# Joe Moreira       5.0
# Vitor Miranda     5.0
# Hector Lombard    5.0
# Sergio Moraes     4.0
# Lorenz Larkin     4.0
# Sammy Morgan      4.0
# Joe Proctor       4.0
# Viktor Pešta      4.0
# Conor McGregor    4.0
# dtype: float64
#
# Kiuma Kunioku
# -------------
# Kiichi Kunimoto             5.0
# Kuniyoshi Hironaka          4.0
# Junior Assunção             4.0
# Junior dos Santos           4.0
# Hatsu Hioki                 3.0
# Kazuki Tokudome             3.0
# Antônio Silva               3.0
# Antônio Rogério Nogueira    3.0
# Tatsuya Kawajiri            3.0
# Antônio Rodrigo Nogueira    3.0
# dtype: float64

# %%
fighter_urls.loc['Masanori Kanehara']
# Out:
# URL    https://en.wikipedia.org/wiki/Masanori_Kanehara
# Name: Masanori Kanehara, dtype: object

# %%
opponent_name_mapper2 = {}
opponent_name_mapper2['Tank Abbott'] = 'David Abbott'
opponent_name_mapper2['Ovince Saint Preux'] = 'Ovince St. Preux'
opponent_name_mapper2['Oleksiy Oliynyk'] = 'Alexey Oleinik'

raw_data['Opponent'] = raw_data['Opponent'].apply(lambda x: opponent_name_mapper2[x] if x in opponent_name_mapper2 else x) 
perc_opponent_recognized()
# Out:
# Percent opponents are familiar fighters: 38.52%

# %% [markdown]
# ### Final reformat and save

# %%
raw_data['birthday'] = pd.to_datetime(raw_data['birthday'], errors='coerce')
# Out:
# Index(['', 'Res.', 'Record', 'Opponent', 'Method', 'Event', 'Date', 'Round',
#        'Time', 'Location', 'Notes', '', 'birthday', 'Fighter', 'Date_new'],
#       dtype='object')

# %%
raw_data = raw_data.loc[~raw_data['Res.'].isin(['TBD','NC','']),:]
raw_data['Res.'].unique()
# Out:
# array(['Loss', 'Win', 'Draw', 'win', 'loss', 'Won', 'Winx', 'Lossx', 'xWin'], dtype=object)

# %%
Res_map = {}
Res_map['Loss'] = -1
Res_map['Lossx'] = -1
Res_map['loss'] = -1
Res_map['Win'] = 1
Res_map['win'] = 1
Res_map['Won'] = 1
Res_map['Winx'] = 1
Res_map['xWin'] = 1
Res_map['Draw'] = 0

raw_data['Result'] = raw_data['Res.'].apply(lambda x: Res_map[x])

# %%
raw_data.head(3)
# Out:
#      Res.   Record       Opponent                 Method  \
# 0    Loss  30–14–1   Justin Salas       Decision (split)
# 1    Loss  30–13–1  Tony Ferguson  TKO (corner stoppage)
# 2     Win  30–12–1    Joe Brammer   Decision (unanimous)
#
#                             Event                                       Date  \
# 0  UFC on Fox: Johnson vs. Moraga       000000002013-07-27-0000July 27, 2013
# 1                         UFC 135  000000002011-09-24-0000September 24, 2011
# 2                         UFC 114        000000002010-05-29-0000May 29, 2010
#
#   Round  Time                            Location Notes      birthday  \
# 0     3  5:00  Seattle, Washington, United States          1980-12-09
# 1     1  5:00     Denver, Colorado, United States          1980-12-09
# 2     3  5:00    Las Vegas, Nevada, United States          1980-12-09
#
#        Fighter   Date_new  Result
# 0  Aaron Riley 2013-07-27      -1
# 1  Aaron Riley 2011-09-24      -1
# 2  Aaron Riley 2010-05-29       1

# %%
final_columns = ['Fighter','Opponent','Date_new','birthday','Result','Round','Time','Location','Method']

data = raw_data[final_columns]
data = data.rename(columns = {'birthday':'fighter_birthday','Date_new':'Date'})
data.head(3)
data.to_csv('./Data/fights.csv',index=False)
