# %% [markdown]
# # Determine list of UFC fighters and their URLs
#
# Let's go to https://en.wikipedia.org/wiki/List_of_male_mixed_martial_artists and extract all names/urls with 'UFC' next them

# %%
import pandas as pd

#scraping
import requests
from bs4 import BeautifulSoup

# %%
fighters_list_page = requests.get('https://en.wikipedia.org/wiki/List_of_male_mixed_martial_artists')
soup = BeautifulSoup(fighters_list_page.content, 'html.parser')

# %%
soup = BeautifulSoup(fighters_list_page.content,'html.parser')

# %%
name_exceptions = {}
name_exceptions['Tim Hague (†)- (KOTC, UFC, MFC, WSOF)'] = 'Tim Hague'
name_exceptions['Kevin Randleman (†) - (PRIDE, UFC, Sengoku, Strikeforce)'] = 'Kevin Randleman'

def remove_nick_name(name):
    if '"' in name:
        left = name[:name.index('"')]
        right = name[name.index('"')+1:]
        right = right[right.index('"')+2:]
        return left + right
    else:
        return name

def clean_name(name):
    name = name.lstrip()
    if name in name_exceptions:
        return name_exceptions[name]
    else:
        idx = name.index(' - ')
        if '[' in name:
            idx = min(idx,name.index('['))
        name = remove_nick_name(name[:idx])
        return name.rstrip()

ufc_names = []

for li in soup.findAll('li')[26:]:
    txt = li.get_text()
    if 'UFC' in txt:
        ufc_names.append(clean_name(li.get_text()))
        
ufc_names
# Out:
# ['David Abbott',
#  'Papy Abedi',
#  'Sam Adkins',
#  'Omari Akhmedov',
#  'Yoshihiro Akiyama',
#  'Mostapha Al-Turk',
#  'John Albert',
#  'Ildemar Alcântara',
#  'Iuri Alcântara',
#  'José Aldo',
#  'John Alessio',
#  'Houston Alexander',
#  'Royce Alger',
#  'Sultan Aliev',
#  'Ben Alloway',
#  'Ricardo Almeida',
#  'Thomas Almeida',
#  'Eddie Alvarez',
#  'Sean Alvarez',
#  'Thiago Alves',
#  'Warlley Alves',
#  'Sam Alvey',
#  'Adlan Amagov',
#  'Makwan Amirkhani',
#  'Corey Anderson',
#  'Alex Andrade',
#  'Viscardi Andrade',
#  'Dylan Andrews',
#  'Reese Andy',
#  'Yoji Anjo',
#  'Gadzhimurad Antigulov',
#  'Felipe Arantes',
#  'Andrei Arlovski',
#  'Matt Arroyo',
#  'Junior Assunção',
#  'Raphael Assunção',
#  'Rich Attonito',
#  'Olivier Aubin-Mercier',
#  'Marcus Aurélio',
#  'Niklas Bäckström',
#  'Seth Baczynski',
#  'Ryan Bader',
#  'Ali Bagautinov',
#  'Siyar Bahadurzada',
#  'Shamar Bailey',
#  'Antonio Banuelos',
#  'Renan Barão',
#  'Bryan Barberena',
#  'Edson Barboza',
#  'Luke Barnatt',
#  'Josh Barnett',
#  'David Baron',
#  'Phil Baroni',
#  'Carlos Barreto',
#  'Francimar Barroso',
#  'Pat Barry',
#  'Enrique Barzola',
#  'Chris Beal',
#  'Johnny Bedford',
#  'Mirsad Bektić',
#  'Alan Belcher',
#  'Vitor Belfort',
#  'Joey Beltran',
#  'Joseph Benavidez',
#  'Dave Beneteau',
#  'Gabriel Benítez',
#  'Lance Benoist',
#  'Ryan Benoit',
#  'Steve Berger',
#  'Dennis Bermudez',
#  'Rony Mariano Bezerra',
#  'Magomed Bibulatov',
#  'David Bielkheden',
#  'Michael Bisping',
#  'Jan Blachowicz',
#  'Jason Black',
#  'Brad Blackburn',
#  'Maximo Blanco',
#  'Dan Bobish',
#  'Mark Bocek',
#  'Kyle Bochniak',
#  'Tim Boetsch',
#  'Jerry Bohlander',
#  'Stephan Bonnar',
#  'Ray Borg',
#  'Marcus Bossett',
#  'Brian Bowles',
#  'Roger Bowling',
#  'Kyle Bradley',
#  'Paul Bradley',
#  'Ebenezer Fontes Braga',
#  'David Branch',
#  'Diego Brandão',
#  'Tom Breese',
#  'Chris Brennan',
#  'Charlie Brenneman',
#  'Jason Brilz',
#  'Marcus Brimage',
#  'Henry Briones',
#  'Jonathan Brookins',
#  'Jarred Brooks',
#  'Will Brooks',
#  'Rob Broughton',
#  'Damien Brown',
#  'Matt Brown',
#  'Mike Brown',
#  'Travis Browne',
#  'Junie Browning',
#  'Steve Bruno',
#  'Derek Brunson',
#  'Justin Buchholz',
#  'Paul Buentello',
#  'Josh Burkman',
#  'Mikey Burnett',
#  'Gilbert Burns',
#  'Kevin Burns',
#  'Nah-Shon Burrell',
#  'Murilo Bustamante',
#  'Alex Caceres',
#  'Fabrício Camões',
#  'Brian Camozzi',
#  'Chris Camozzi',
#  'Will Campuzano',
#  'Chico Camus',
#  'Luiz Cané',
#  'Guido Cannetti',
#  'Steve Cantwell',
#  'Bryan Caraway',
#  'Chris Cariaso',
#  'Antônio Carlos Júnior',
#  'Francis Carmont',
#  'Roan Carneiro',
#  'Shonie Carter',
#  'Antonio Carvalho',
#  'Shane Carwin',
#  'Johnny Case',
#  'Kevin Casey',
#  'Danny Castillo',
#  'Gil Castillo',
#  'Nick Catone',
#  'Luke Caudillo',
#  'Rafael Cavalcante',
#  'Magnus Cedenblad',
#  'Yosdenis Cedeno',
#  'Henry Cejudo',
#  'Donald Cerrone',
#  'Ernest Chavez',
#  'Michael Chiesa',
#  'Sako Chivitchian',
#  'Doo Ho Choi',
#  'John Cholish',
#  'Ryo Chonan',
#  'Joachim Christensen',
#  'Dan Christison',
#  'Devin Clark',
#  'LaVerne Clark',
#  'Logan Clark',
#  'Mitch Clarke',
#  'Rich Clementi',
#  'Chris Clements',
#  'Mark Coleman',
#  'Carlos Condit',
#  'Chris Cope',
#  'Kit Cope',
#  'Akira Corassani',
#  'Daniel Cormier',
#  'Wesley Correira',
#  'Patrick Côté',
#  'Randy Couture',
#  'Ryan Couture',
#  'Colby Covington',
#  'Andrew Craig',
#  'Dan Cramer',
#  'Alberto Crane',
#  'Tim Credeur',
#  'Paul Creighton',
#  'Daron Cruickshank',
#  'Richard Crunkilton',
#  'Dominick Cruz',
#  'Márcio Cruz',
#  'Zak Cummings',
#  'Patrick Cummins',
#  'Luke Cummo',
#  'Jeff Curran',
#  'Henrique da Silva',
#  'Jussier da Silva',
#  'Paul Daley',
#  'Rodrigo Damm',
#  'Alexandre Dantas',
#  'Mac Danzig',
#  'Beneil Dariush',
#  'Marcus Davis',
#  'Phil Davis',
#  'Jason Day',
#  'Phil De Fries',
#  'Mike De La Torre',
#  'Shane del Rosario',
#  'Tom DeBlass',
#  'Rolando Delgado',
#  'Roland Delorme',
#  'Jason DeLucia',
#  'Nick Denis',
#  'Jason Dent',
#  'Tony DeSouza',
#  'Edwin Dewees',
#  'Cyrille Diabaté',
#  'Hacran Dias',
#  'Nate Diaz',
#  'Nick Diaz',
#  'Alessio Di Chirico',
#  'T.J. Dillashaw',
#  'Russell Doane',
#  'Drew Dober',
#  'John Dodson',
#  'Joe Doerksen',
#  'C.B. Dollaway',
#  'Cody Donovan',
#  'Rafael dos Anjos',
#  'Junior dos Santos',
#  'Danny Downes',
#  'Tomasz Drwal',
#  'Robert Drysdale',
#  'Todd Duffee',
#  'Kelly Dullanty',
#  'Evan Dunham',
#  'Tom Duquesnoy',
#  'Reuben Duran',
#  'Matt Dwyer',
#  'Marvin Eastman',
#  'Mike Easton',
#  'Brian Ebersole',
#  'Mark Eddiva',
#  'Frankie Edgar',
#  'Johnny Eduardo',
#  'Justin Edwards',
#  'Leon Edwards',
#  'Yves Edwards',
#  'Justin Eilers',
#  'Jon Olav Einemo',
#  'Per Eklund',
#  'Darren Elkins',
#  'Jake Ellenberger',
#  'Tim Elliott',
#  'Rob Emerson',
#  'Josh Emmett',
#  'Cole Escovedo',
#  'Efrain Escudero',
#  'Terry Etim',
#  'Doug Evans',
#  'Rashad Evans',
#  'Dan Evensen',
#  'Edward Faaloloto',
#  'Urijah Faber',
#  'Maiquel Falcão',
#  'Brodie Farber',
#  'Paul Felder',
#  'Kevin Ferguson',
#  'Tony Ferguson',
#  'Alexandre Ferreira',
#  'Carlos Diego Ferreira',
#  'Cezar Ferreira',
#  'Scott Ferrozzo',
#  'Drew Fickett',
#  'Edwin Figueroa',
#  'Andre Fili',
#  'Mirko Filipović',
#  'Luigi Fioravanti',
#  'Spencer Fisher',
#  'Jon Fitch',
#  'Colin Fletcher',
#  'Kenny Florian',
#  'Caros Fodor',
#  'Jesse Forbes',
#  'Renee Forte',
#  'Brian Foster',
#  'Hermes França',
#  'Rich Franklin',
#  'Zane Frazier',
#  'Ian Freeman',
#  'Willamy Freire',
#  'Don Frye',
#  'Tony Fryklund',
#  'Katsuhisa Fujii',
#  'Riki Fukuda',
#  'Travis Fulton',
#  'Ricardo Funch',
#  'Mitch Gagnon',
#  'Mickey Gall',
#  'Manvel Gamburyan',
#  'Alex Garcia',
#  'Edgar Garcia',
#  'Leonard Garcia',
#  'Cody Garbrandt',
#  'Pablo Garza',
#  'Brian Gassaway',
#  'Kelvin Gastelum',
#  'Louis Gaudinot',
#  'Tiki Ghosn',
#  'Cody Gibson',
#  'Lance Gibson',
#  'Bob Gilstrap',
#  'Mark Godbeer',
#  'Allan Goes',
#  'Ulysses Gomez',
#  'Takanori Gomi',
#  'Akihiro Gono',
#  'Gabriel Gonzaga',
#  'Lyman Good',
#  'Gary Goodridge',
#  'Gerard Gordeau',
#  'Eddie Gordon',
#  'Jared Gordon',
#  'Jonathan Goulet',
#  'Wilson Gouveia',
#  'Renzo Gracie',
#  'Roger Gracie',
#  'Rolles Gracie',
#  'Royce Gracie',
#  'TJ Grant',
#  'Bobby Green',
#  'Desmond Green',
#  'Matt Grice',
#  'Forrest Griffin',
#  'Tyson Griffin',
#  'Chad Griggs',
#  'Josh Grispi',
#  'Kendall Grove',
#  'Neil Grove',
#  'Vik Grujic',
#  'Shannon Gugerty',
#  'Clay Guida',
#  'Melvin Guillard',
#  'Marcelo Guimarães',
#  'John Gunderson',
#  'Fabio Gurgel',
#  'Jorge Gurgel',
#  'Alexander Gustafsson',
#  'Mike Guymon',
#  'Keith Hackney',
#  'Damir Hadzovic',
#  'Tim Hague',
#  'Mark Hall',
#  'Ryan Hall',
#  'Uriah Hall',
#  'Dennis Hallman',
#  'Piotr Hallmann',
#  'Tony Halme',
#  'Matt Hamill',
#  'Anthony Hamilton',
#  'Jared Hamman',
#  'Antoni Hardonk',
#  'Dan Hardy',
#  'Gerald Harris',
#  'Phil Harris',
#  'Walt Harris',
#  'Dale Hartt',
#  'Clay Harvison',
#  'Chris Haseman',
#  'John Hathaway',
#  'Josh Haynes',
#  'Dustin Hazelett',
#  'James Head',
#  'Pat Healy',
#  'David Heath',
#  'Jake Hecht',
#  'Nick Hein',
#  'Marcin Held',
#  'Benson Henderson',
#  'Dan Henderson',
#  'Johny Hendricks',
#  'Dave Herman',
#  'Ed Herman',
#  'Heath Herring',
#  'Jon Hess',
#  'Clint Hester',
#  'Jimy Hettes',
#  'Jay Hieron',
#  'Jason High',
#  'Corey Hill',
#  'Branden Lee Hinkle',
#  'Hatsu Hioki',
#  'Kuniyoshi Hironaka',
#  'Mizuto Hirota',
#  'Matt Hobar',
#  'Bobby Hoffman',
#  'Sam Hoger',
#  'Andrew Holbrook',
#  'Chris Holdsworth',
#  'Roger Hollett',
#  'Max Holloway',
#  'Patrick Holohan',
#  'Mark Holst',
#  'Mark Hominick',
#  'Satoshi Honma',
#  'Darrell Horcher',
#  'Kyoji Horiguchi',
#  'Jeremy Horn',
#  'Matt Horwich',
#  'Jeff Hougland',
#  'Harold Howard',
#  'John Howard',
#  'Shane Howell',
#  'Roger Huerta',
#  'Mark Hughes',
#  'Matt Hughes',
#  'Mark Hunt',
#  'Solomon Hutcherson',
#  'Al Iaquinta',
#  'Fabiano Iha',
#  'Brad Imes',
#  'Guto Inocente',
#  'Enson Inoue',
#  'James Irvin',
#  'Wallid Ismail',
#  'Leandro Issa',
#  'Yves Jabouin',
#  'Damon Jackson',
#  'Jeremy Jackson',
#  'Kevin Jackson',
#  'Quinton Jackson',
#  'Dustin Jacoby',
#  'Ryan Janes',
#  'Keith Jardine',
#  'Trent Jenkins',
#  'Steve Jennum',
#  'Ryan Jensen',
#  'Maciej Jewtuszko',
#  'Ronald Jhun',
#  'Art Jimmerson',
#  'Ryan Jimmo',
#  'Li Jingliang',
#  'Brett Johns',
#  'Anthony Johnson',
#  'DaMarques Johnson',
#  'Demetrious Johnson',
#  'Lavar Johnson',
#  'Michael Johnson',
#  'Brian Johnston',
#  'Jon Jones',
#  'Marcus Jones',
#  'Paul Jones',
#  'Kevin Jordan',
#  'Shawn Jordan',
#  'Ivan Jorge',
#  'Scott Jorgensen',
#  'Krzysztof Jotko',
#  'Alan Jouban',
#  'Luke Jumeau',
#  'Chan Sung Jung',
#  'Myles Jury',
#  'Martin Kampmann',
#  'Masanori Kanehara',
#  'Denis Kang',
#  'Kyung Ho Kang',
#  'Alex Karalexis',
#  'Tatsuya Kawajiri',
#  'Chris Kelades',
#  'Daniel Kelly',
#  'Paul Kelly',
#  'Tim Kennedy',
#  'Mark Kerr',
#  'Rustam Khabilov',
#  'Katsunori Kikuno',
#  'Sanae Kikuta',
#  'Dong Hyun Kim',
#  'Dong Hyun Kim',
#  'Rob Kimmons',
#  'Dustin Kimura',
#  'Kyle Kingsbury',
#  'Koji Kitao',
#  'Erik Koch',
#  'Brad Kohler',
#  'Tsuyoshi Kohsaka',
#  'John Kolosci',
#  'Yuki Kondo',
#  'Cheick Kongo',
#  'Josh Koscheck',
#  'Naoyuki Kotani',
#  'James Krause',
#  'Pascal Krauss',
#  'Jörgen Kruth',
#  'Nikita Krylov',
#  'Michael Kuiper',
#  'Anton Kuivanen',
#  'Kiichi Kunimoto',
#  'Kwan Ho Kwak',
#  'Mike Kyle',
#  'Ryan LaFlare',
#  'Tim Lajcik',
#  'Ricardo Lamas',
#  'Jason Lambert',
#  'Chad Laprise',
#  'Anthony Lapsley',
#  'Lorenz Larkin',
#  'Jeremy Larsen',
#  'Brock Larson',
#  'Ilir Latifi',
#  'Dan Lauzon',
#  'Joe Lauzon',
#  'Robbie Lawler',
#  'Tom Lawlor',
#  'Justin Lawrence',
#  'Cung Le',
#  'Chris Leben',
#  'Vaughan Lee',
#  'Thales Leites',
#  'Jesse Lennox',
#  'Nik Lentz',
#  'Kimo Leopoldo',
#  'Brock Lesnar',
#  'Justin Levens',
#  'Marcus LeVesseur',
#  'Derrick Lewis',
#  'Jess Liaudin',
#  'Chuck Liddell',
#  'Zach Light',
#  'Chris Liguori',
#  'Hyun Gyu Lim',
#  'Dhiego Lima',
#  'Matt Lindland',
#  'Jake Lindsey',
#  'John Lineker',
#  'Dean Lister',
#  'John Lober',
#  'David Loiseau',
#  'Hector Lombard',
#  'Matthew Lopez',
#  'Nate Loughran',
#  'Ian Loveland',
#  'Waylon Lowe',
#  'Duane Ludwig',
#  'Travis Lutter',
#  'Chris Lytle',
#  'William Macário',
#  'Jason MacDonald',
#  'Rob MacDonald',
#  'Rory MacDonald',
#  'Lyoto Machida',
#  'War Machine',
#  'Anthony Macias',
#  'Reza Madadi',
#  'Jon Madsen',
#  'Leonardo Mafra',
#  'Caio Magalhães',
#  'Vinny Magalhães',
#  'Neil Magny',
#  'Rashid Magomedov',
#  'Ruslan Magomedov',
#  'John Maguire',
#  'Demian Maia',
#  'John Makdessi',
#  'Islam Makhachev',
#  'Zach Makovsky',
#  'Fábio Maldonado',
#  'Jimi Manuwa',
#  'Cristiano Marcello',
#  'Ronny Markes',
#  'Rory Markham',
#  'Nate Marquardt',
#  'Carmelo Marrero',
#  'John Marsh',
#  'Eliot Marshall',
#  'Jack Marshman',
#  'Terry Martin',
#  'Tony Martin',
#  'Danny Martinez',
#  'Henry Martinez',
#  'Adriano Martins',
#  'Lucas Martins',
#  'Bristol Marunde',
#  'Mike Massenzio',
#  'Jorge Masvidal',
#  'Jake Matthews',
#  'Vladimir Matyushenko',
#  'Gray Maynard',
#  'Ian McCall',
#  'Charles McCarthy',
#  'Sean McCorkle',
#  'Kris McCray',
#  'Tamdan McCrory',
#  'Justin McCully',
#  'Robert McDaniel',
#  'Michael McDonald',
#  'Drew McFedries',
#  'Court McGee',
#  'Gan McGee',
#  'Conor McGregor',
#  'Antonio McKee',
#  'Cody McKenzie',
#  'Tim McKenzie',
#  'James McSweeney',
#  'Tim Means',
#  'Yancy Medeiros',
#  'Jordan Mein',
#  'Brian Melancon',
#  'Gilbert Melendez',
#  'Chad Mendes',
#  'Ivan Menjivar',
#  'Dave Menne',
#  'Yaotzin Meza',
#  'Guy Mezger',
#  'David Michaud',
#  'Pat Miletich',
#  'Cole Miller',
#  'Dan Miller',
#  'Jason Miller',
#  'Jim Miller',
#  'Phillip Miller',
#  'Che Mills',
#  'Stipe Miocic',
#  'Frank Mir',
#  'Mario Miranda',
#  'Vitor Miranda',
#  'Dokonjonosuke Mishima',
#  'David Mitchell',
#  'Felix Mitchell',
#  'Matt Mitrione',
#  'Eiji Mitsuoka',
#  'Takeya Mizugaki',
#  'Nate Mohr',
#  'Ashkan Mokhtarian',
#  'Jeff Monson',
#  'Darrell Montague',
#  'Augusto Montaño',
#  'James Moontasri',
#  'Homer Moore',
#  'Sergio Moraes',
#  'John Moraga',
#  'Christian Morecraft',
#  'Joe Moreira',
#  'Sammy Morgan',
#  'Gegard Mousasi',
#  'Quinn Mulhern',
#  'Pedro Munhoz',
#  'Mark Muñoz',
#  'Lee Murray',
#  'Nico Musoke',
#  'Ashkan Mokhtarian',
#  'Kazuhiro Nakamura',
#  'Keita Nakamura',
#  'Jutaro Nakao',
#  'Yui Chul Nam',
#  'Roger Narvaez',
#  'Rafael Natal',
#  'Dustin Neace',
#  'Stanislav Nedkov',
#  'Josh Neer',
#  'Steve Nelmark',
#  'Gunnar Nelson',
#  'Roy Nelson',
#  'Shane Nelson',
#  'Antonio Braga Neto',
#  'Mario Neto',
#  'Carlos Newton',
#  'Tom Niinimäki',
#  'Ramsey Nijem',
#  'Mats Nilsson',
#  'Jack Nilson',
#  'Anthony Njokuani',
#  'Antônio Rodrigo Nogueira',
#  'Antônio Rogério Nogueira',
#  'Kyle Noke',
#  'KJ Noons',
#  'Sage Northcutt',
#  'Phillipe Nover',
#  'Diego Nunes',
#  'Khabib Nurmagomedov',
#  "Jake O'Brien",
#  "Sean O'Connell",
#  'Andy Ogle',
#  'Yushin Okami',
#  'Alexey Oleinik',
#  'Charles Oliveira',
#  'Rafaello Oliveira',
#  "Sean O'Malley",
#  'Daniel Omielańczuk',
#  'Michihiro Omigawa',
#  "Chuck O'Neil",
#  'Brian Ortega',
#  'Dustin Ortiz',
#  'Tito Ortiz',
#  'Nick Osipczak',
#  'Zak Ottow',
#  'Alistair Overeem',
#  'Alptekin Özkiliç',
#  'Nick Pace',
#  'Damacio Page',
#  'Dustin Pague',
#  'Fredson Paixão',
#  'Teemu Packalen',
#  'Bart Palaszewski',
#  'Soa Palelei',
#  'Rousimar Palhares',
#  'Jared Papazian',
#  'Remco Pardoel',
#  'Karo Parisyan',
#  'Norman Parke',
#  'Jorge Patino',
#  'Alan Patrick',
#  'Claude Patrick',
#  'Estevan Payan',
#  'Ross Pearson',
#  'André Pederneiras',
#  'Tyson Pedro',
#  'Kurt Pellegrino',
#  'Sherman Pendergarst',
#  'Cathal Pendred',
#  'B.J. Penn',
#  'Godofredo Pepey',
#  'Robbie Peralta',
#  'Alejandro Pérez',
#  'Érik Pérez',
#  'Anthony Perosh',
#  'Thiago Perpétuo',
#  'Viktor Pešta',
#  'Seth Petruzelli',
#  'Anthony Pettis',
#  'Sergio Pettis',
#  'Forrest Petz',
#  'Nam Phan',
#  'Costas Philippou',
#  'Vinc Pichel',
#  'Brad Pickett',
#  'Mike Pierce',
#  'Sean Pierson',
#  'Daniel Pineda',
#  'Dustin Poirier',
#  'Igor Pokrajac',
#  'John Polakowski',
#  'Marco Polo Reyes',
#  'Ruan Potts',
#  'Wagner Prado',
#  'Trevor Prangley',
#  'Carlo Prater',
#  'Michel Prazeres',
#  'Joe Proctor',
#  'Jens Pulver',
#  'CM Punk',
#  'Mike Pyle',
#  'Nathan Quarry',
#  'Vinicius Queiroz',
#  'José Alberto Quiñónez',
#  'Benji Radach',
#  'Jordan Radev',
#  'Hector Ramirez',
#  'Luis Ramos',
#  'Ricardo Ramos',
#  'Kevin Randleman',
#  'Gideon Ray',
#  'Chad Reiner',
#  'Jason Reinhardt',
#  'Wilson Reis',
#  'Goran Reljić',
#  'Johnny Rhodes',
#  'Mike Ricci',
#  'Matthew Riddle',
#  'Joe Riggs',
#  'Aaron Riley',
#  'Nick Ring',
#  'Mike Rio',
#  'Dante Rivera',
#  'Francisco Rivera',
#  'Jorge Rivera',
#  'Pedro Rizzo',
#  'Andre Roberts',
#  'Daniel Roberts',
#  'Danny Roberts',
#  'Kenny Robertson',
#  'Alvin Robinson',
#  'Carlos Eduardo Rocha',
#  'Vagner Rocha',
#  'Luke Rockhold',
#  'Ricco Rodriguez',
#  'Yair Rodríguez',
#  'Shane Roller',
#  'Ricardo Romero',
#  'Yoel Romero',
#  'Jesse Ronson',
#  'George Roop',
#  'João Roque',
#  'Aaron Rosa',
#  'Charles Rosa',
#  'Jake Rosholt',
#  'Jared Rosholt',
#  'Kevin Rosier',
#  'Ben Rothwell',
#  'Mauricio Rua',
#  'Marco Ruas',
#  'Gabe Ruediger',
#  'Mike Russow',
#  'Bas Rutten',
#  'Amir Sadollah',
#  'Frankie Saenz',
#  'Tarec Saffiedine',
#  'Alessio Sakara',
#  'Kazushi Sakuraba',
#  'Hayato Sakurai',
#  'Justin Salas',
#  'Ivan Salaverry',
#  'Sean Salmon',
#  'John Salter',
#  'Josh Samman',
#  'Josh Sampo',
#  'Diego Sanchez',
#  'Eddie Sanchez',
#  'Jorge Santiago',
#  'Bruno Santos',
#  'Iliarde Santos',
#  'Leonardo Santos',
#  'Thiago Santos',
#  'Daniel Sarafian',
#  'Diego Saraiva',
#  'Yuki Sasaki',
#  'Yuta Sasaki',
#  'Paul Sass',
#  'Takenori Sato',
#  'Ben Saunders',
#  'Townsend Saunders',
#  'Eric Schafer',
#  'Kerry Schall',
#  'Brendan Schaub',
#  'Fabiano Scherner',
#  'Samy Schiavo',
#  'Semmy Schilt',
#  'Mark Schultz',
#  'Justin Scoggins',
#  'Brad Scott',
#  'Neil Seery',
#  'Pete Sell',
#  'Andrei Semenov',
#  'Mackens Semerzier',
#  'Matt Serra',
#  'Dan Severn',
#  'Kamal Shalorus',
#  'Frank Shamrock',
#  'Ken Shamrock',
#  'Sean Sherk',
#  'Jake Shields',
#  'Josh Shockley',
#  'Sam Sicilia',
#  'Steven Siler',
#  'Anderson Silva',
#  'Antônio Silva',
#  'Assuerio Silva',
#  'Cláudio Silva',
#  'Erick Silva',
#  'Jay Silva',
#  'Joaquim Silva',
#  'Thiago Silva',
#  'Wanderlei Silva',
#  'Elias Silvério',
#  'Aaron Simpson',
#  'Wes Sims',
#  'Lodune Sincaid',
#  'Rory Singer',
#  'Elvis Sinosic',
#  'Dennis Siver',
#  'Chas Skelly',
#  'Joe Slick',
#  'Anthony Smith',
#  'Colton Smith',
#  'Maurice Smith',
#  'Patrick Smith',
#  'Scott Smith',
#  'Trevor Smith',
#  'Louis Smolka',
#  'Peter Sobotta',
#  'Renato Sobral',
#  'Rameau Thierry Sokoudjou',
#  'Joe Son',
#  'Chael Sonnen',
#  'Sean Soriano',
#  'Krzysztof Soszynski',
#  'George Sotiropoulos',
#  'Greg Soto',
#  'Joe Soto',
#  'Bobby Southworth',
#  'Kevin Souza',
#  'Ronaldo Souza',
#  'Chris Spång',
#  'Tom Speer',
#  'Sean Spencer',
#  'Dan Spohn',
#  'Pete Spratt',
#  'Ron Stallings',
#  'Brian Stann',
#  'Clifford Starks',
#  'Kalib Starnes',
#  'Steve Steinbeiss',
#  'Jeremy Stephens',
#  'Aljamain Sterling',
#  'Joe Stevenson',
#  'Alex Stiebling',
#  'Ken Stone',
#  'Rick Story',
#  'Sam Stout',
#  'Georges St-Pierre',
#  'Ovince St. Preux',
#  'Dave Strasser',
#  'Gerald Strebendt',
#  'Sean Strickland',
#  'Stefan Struve',
#  'Genki Sudo',
#  'George Sullivan',
#  'Amar Suloev',
#  'Cub Swanson',
#  'Mike Swick',
#  'Tim Sylvia',
#  'Mairbek Taisumov',
#  'Kazuo Takahashi',
#  'Daiju Takase',
#  'Oleg Taktarov',
#  'Nordine Taleb',
#  'Issei Tamura',
#  'Jason Tan',
#  'Michinori Tanaka',
#  'Evan Tanner',
#  'Brad Tavares',
#  'Thiago Tavares',
#  'Jesse Taylor',
#  'Louis Taylor',
#  'Paul Taylor',
#  'James Te Huna',
#  'Glover Teixeira',
#  'John Teixeira',
#  'Tra Telligman',
#  'David Terrell',
#  'Brandon Thatch',
#  'Elias Theodorou',
#  'Paulo Thiago',
#  'Nick Thompson',
#  'Oli Thompson',
#  'Stephen Thompson',
#  'Josh Thomson',
#  'Din Thomas',
#  'Ryan Thomas',
#  'Simeon Thoresen',
#  'Gleison Tibau',
#  'Darren Till',
#  'Kazuki Tokudome',
#  'Tyler Toner',
#  'James Toney',
#  'Miguel Torres',
#  'Roberto Traven',
#  'Frank Trigg',
#  'Francisco Trinaldo',
#  'Tor Troéng',
#  'Abel Trujillo',
#  'Chris Tuchscherer',
#  'Jon Tuck',
#  'Jumabieke Tuerxun',
#  'Zubaira Tukhugov',
#  'Teila Tuli',
#  'Albert Tumenov',
#  'Gasan Umalatov',
#  'Caol Uno',
#  'Yasuhiro Urushitani',
#  'Darren Uyenoyama',
#  'Charlie Valencia',
#  'Isaac Vallie-Flagg',
#  'Mike Van Arsdale',
#  'Matt Van Buren',
#  'Ron van Clief',
#  'Paul Varelans',
#  'Jamie Varner',
#  'Javier Vazquez',
#  'Matt Veach',
#  'Joe Vedepo',
#  'Cain Velasquez',
#  'Bojan Veličković',
#  'Karlos Vemola',
#  'Brandon Vera',
#  'Renato Verissimo',
#  'Marvin Vettori',
#  'Hugo Viana',
#  'James Vick',
#  'Milton Vieira',
#  'Steve Vigneault',
#  'Gian Villante',
#  'Danillo Villefort',
#  'Yuri Villefort',
#  'Marcos Vinicius',
#  'Falaniko Vitale',
#  'Bobby Voelker',
#  'Alexander Volkanovski',
#  'Jacob Volkmann',
#  'Jason Von Flue',
#  'Chris Wade',
#  'TJ Waldburger',
#  'Donny Walker',
#  'Crafton Wallace',
#  'Rodney Wallace',
#  'Cory Walmsley',
#  'Richard Walsh',
#  'Curt Warburton',
#  'Ron Waterman',
#  'Tom Watson',
#  'Walel Watson',
#  'Royston Wee',
#  'Chris Weidman',
#  ...]

# %%
url_exceptions = {}
url_exceptions['Mostapha Al-Turk'] = 'https://en.wikipedia.org/wiki/Mostapha_al-Turk'
url_exceptions['Ryan Janes'] = 'https://en.wikipedia.org/wiki/Ryan_Janes_(fighter)'
url_exceptions['Lipeng Zhang'] = 'https://en.wikipedia.org/wiki/Zhang_Lipeng'

def form_fighter_url(name):
    url_guess = 'https://en.wikipedia.org/wiki/' + name.replace(' ','_')
    url_guess_fighter = url_guess + '_(fighter)'
    if requests.head(url_guess_fighter).status_code == 200:
        return url_guess_fighter
    elif requests.head(url_guess).status_code == 200:
        return url_guess
    elif name in url_exceptions:
        return url_exceptions[name]
    else:
        print('No URL: {0}, {1}'.format(name,url_guess))
    
urls = {}

for name in ufc_names:
    url = form_fighter_url(name)
    if url:
        urls[name] = url

# %%
urls_df = pd.DataFrame(pd.Series(urls),columns=['URL']).reset_index().rename(columns={'index':'Name'})
urls_df.to_csv('.\Data\FighterURLs.csv',index=False)
urls_df.head(20)
# Out:
#                   Name                                               URL
# 0          Aaron Riley         https://en.wikipedia.org/wiki/Aaron_Riley
# 1           Aaron Rosa          https://en.wikipedia.org/wiki/Aaron_Rosa
# 2        Aaron Simpson       https://en.wikipedia.org/wiki/Aaron_Simpson
# 3        Abel Trujillo       https://en.wikipedia.org/wiki/Abel_Trujillo
# 4         Adlan Amagov        https://en.wikipedia.org/wiki/Adlan_Amagov
# 5      Adriano Martins     https://en.wikipedia.org/wiki/Adriano_Martins
# 6         Akihiro Gono        https://en.wikipedia.org/wiki/Akihiro_Gono
# 7      Akira Corassani     https://en.wikipedia.org/wiki/Akira_Corassani
# 8          Al Iaquinta         https://en.wikipedia.org/wiki/Al_Iaquinta
# 9         Alan Belcher        https://en.wikipedia.org/wiki/Alan_Belcher
# 10         Alan Jouban         https://en.wikipedia.org/wiki/Alan_Jouban
# 11        Alan Patrick        https://en.wikipedia.org/wiki/Alan_Patrick
# 12      Albert Tumenov      https://en.wikipedia.org/wiki/Albert_Tumenov
# 13       Alberto Crane       https://en.wikipedia.org/wiki/Alberto_Crane
# 14     Alejandro Pérez     https://en.wikipedia.org/wiki/Alejandro_Pérez
# 15  Alessio Di Chirico  https://en.wikipedia.org/wiki/Alessio_Di_Chirico
# 16      Alessio Sakara      https://en.wikipedia.org/wiki/Alessio_Sakara
# 17        Alex Andrade        https://en.wikipedia.org/wiki/Alex_Andrade
# 18        Alex Caceres        https://en.wikipedia.org/wiki/Alex_Caceres
# 19         Alex Garcia         https://en.wikipedia.org/wiki/Alex_Garcia
